# %% [markdown]
# # Reading  excel file in jupyter notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car = pd.read_excel(r'C:\Users\asus\Downloads\Car_data.xlsx')
car
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP
# 0          BMW  1 Series M  2011     premium unleaded (required)        335  \
# 1          BMW    1 Series  2011     premium unleaded (required)        300
# 2          BMW    1 Series  2011     premium unleaded (required)        300
# 3          BMW    1 Series  2011     premium unleaded (required)        230
# 4          BMW    1 Series  2011     premium unleaded (required)        230
# ...        ...         ...   ...                             ...        ...
# 11807    Acura         ZDX  2012     premium unleaded (required)        300
# 11808    Acura         ZDX  2012     premium unleaded (required)        300
# 11809    Acura         ZDX  2012     premium unleaded (required)        300
# 11810    Acura         ZDX  2013  premium unleaded (recommended)        300
# 11811  Lincoln      Zephyr  2006                regular unleaded        221
#
# ...

# %% [markdown]
# # Dropping null values from the dataset

# %%
car1=car# copying the dataset in car1
#drop all rows that have NaN/None values
car2=car1.dropna()
#car2=car.dropna(axis=0)
car2.notnull().count()#counting the values those are not null
# Out:
# Make                 8084
# Model                8084
# Year                 8084
# Engine Fuel Type     8084
# Engine HP            8084
# Engine Cylinders     8084
# Transmission Type    8084
# Driven_Wheels        8084
# Number of Doors      8084
# Market Category      8084
# Vehicle Size         8084
# Vehicle Style        8084
# highway MPG          8084
# city mpg             8084
# Popularity           8084
# MSRP                 8084
# dtype: int64

# %% [markdown]
# # Unique values in the dataset of MAKE column

# %%
#we can do this with any column  just change it with the [Make]
car["Make"].unique()
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'Toyota',
#        'McLaren', 'Maybach', 'Pontiac', 'Porsche', 'Saab', 'GMC',
#        'Hyundai', 'Plymouth', 'Honda', 'Oldsmobile', 'Suzuki', 'Ford',
#        'Cadillac', 'Kia', 'Bentley', 'Chevrolet', 'Dodge', 'Lamborghini',
#        'Lincoln', 'Subaru', 'Volkswagen', 'Spyker', 'Buick', 'Acura',
#        'Rolls-Royce', 'Maserati', 'Lexus', 'Aston Martin', 'Land Rover',
#        'Lotus', 'Infiniti', 'Scion', 'Genesis', 'HUMMER', 'Bugatti'],
#       dtype=object)

# %%
#null values
car.isnull()
# Out:
#         Make  Model   Year  Engine Fuel Type  Engine HP  Engine Cylinders
# 0      False  False  False             False      False             False  \
# 1      False  False  False             False      False             False
# 2      False  False  False             False      False             False
# 3      False  False  False             False      False             False
# 4      False  False  False             False      False             False
# ...      ...    ...    ...               ...        ...               ...
# 11807  False  False  False             False      False             False
# 11808  False  False  False             False      False             False
# 11809  False  False  False             False      False             False
# 11810  False  False  False             False      False             False
# 11811  False  False  False             False      False             False
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category
# ...

# %% [markdown]
# # Top 10 rows of Make column

# %%
car[car['Make']== 'BMW']
car.head(9)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP
# 0  BMW  1 Series M  2011  premium unleaded (required)        335  \
# 1  BMW    1 Series  2011  premium unleaded (required)        300
# 2  BMW    1 Series  2011  premium unleaded (required)        300
# 3  BMW    1 Series  2011  premium unleaded (required)        230
# 4  BMW    1 Series  2011  premium unleaded (required)        230
# 5  BMW    1 Series  2012  premium unleaded (required)        230
# 6  BMW    1 Series  2012  premium unleaded (required)        300
# 7  BMW    1 Series  2012  premium unleaded (required)        300
# 8  BMW    1 Series  2012  premium unleaded (required)        230
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors
# 0                 6            MANUAL  rear wheel drive                2  \
# 1                 6            MANUAL  rear wheel drive                2
# 2                 6            MANUAL  rear wheel drive                2
# ...

# %% [markdown]
# # count of every column in the dataset

# %%
car1.count()
# Out:
# Make                 11812
# Model                11812
# Year                 11812
# Engine Fuel Type     11812
# Engine HP            11812
# Engine Cylinders     11812
# Transmission Type    11812
# Driven_Wheels        11812
# Number of Doors      11812
# Market Category       8084
# Vehicle Size         11812
# Vehicle Style        11812
# highway MPG          11812
# city mpg             11812
# Popularity           11812
# MSRP                 11812
# dtype: int64

# %% [markdown]
# # Create a pivot table that shows the number of car models in each market category and their corresponding popularity scores.

# %%
pivot_table1 = car.pivot_table(values='Popularity', index='Market Category', columns='Make', aggfunc=['count', 'mean'])
pivot_table1
# Out:
#                                                 count
# Make                                            Acura Alfa Romeo Aston Martin
# Market Category
# Crossover                                         NaN        NaN          NaN  \
# Crossover,Diesel                                  NaN        NaN          NaN
# Crossover,Exotic,Luxury,High-Performance          NaN        NaN          NaN
# Crossover,Exotic,Luxury,Performance               NaN        NaN          NaN
# Crossover,Factory Tuner,Luxury,High-Performance   NaN        NaN          NaN
# ...                                               ...        ...          ...
# Luxury,Hybrid                                     2.0        NaN          NaN
# Luxury,Performance                               57.0        NaN          NaN
# Luxury,Performance,Hybrid                         NaN        NaN          NaN
# Performance                                       NaN        NaN          NaN
# ...

# %% [markdown]
# # Create a pivot table that shows the average price of cars for each manufacturer.

# %%
#pivot_table2 = car.pivot_table(values='MSRP', index='Make', aggfunc='mean')
#pivot_table2
#round(100*(car2.isnull().sum()/len(car2.index)))
# (aggfunc=lambda x: round(x.mean(), 3) in this function we are rounding off the mean 
pivot_table2 = car.pivot_table(values='MSRP', index='Make', aggfunc=lambda x: round(x.mean(), 3))
pivot_table2
# Out:
#                       MSRP
# Make
# Acura            34887.587
# Alfa Romeo       61600.000
# Aston Martin    197910.376
# Audi             53452.113
# BMW              61546.763
# Bentley         247169.324
# Bugatti        1757223.667
# Buick            28206.612
# Cadillac         56231.317
# Chevrolet        28273.357
# Chrysler         26722.963
# Dodge            22390.059
# FIAT             22206.017
# Ferrari         237383.824
# Ford             27393.421
# GMC              30493.299
# Genesis          46616.667
# HUMMER           36464.412
# Honda            26629.819
# Hyundai          24597.036
# Infiniti         42394.212
# Kia              25112.389
# Lamborghini     331567.308
# Land Rover       67823.217
# Lexus            47549.069
# Lincoln          42494.372
# Lotus            69188.276
# Maserati        114207.707
# Maybach         546221.875
# Mazda            19719.057
# McLaren         239805.000
# Mercedes-Benz    71537.810
# Mitsubishi       21215.471
# ...

# %% [markdown]
# # Calculate the correlation coefficient between the number of cylinders and highway MPG to quantify the strength and direction of the relationship.

# %%
corr_coeff = car['Engine Cylinders'].corr(car['highway MPG'])
corr_coeff
# Out:
# -0.6203125511154071

# %% [markdown]
# # Calculate the total MSRP for each brand and body style using  Pivot Tables.

# %%
pivot_table3 = car.pivot_table(values='MSRP', index=['Make', 'Vehicle Style'], aggfunc='sum')
pivot_table3
# Out:
#                         MSRP
# Make  Vehicle Style
# Acura 2dr Hatchback   480917
#       4dr Hatchback   357440
#       4dr SUV        2663505
#       Coupe           793748
#       Sedan          4294702
# ...                      ...
# Volvo 4dr SUV        3219000
#       Convertible     121600
#       Coupe             6000
#       Sedan          2086945
#       Wagon          2428971
#
# [286 rows x 1 columns]

# %% [markdown]
# # Calculate the average MSRP for each brand and body style using  Pivot Tables.

# %%
pivot_table4 = car.pivot_table(values='MSRP', index=['Make', 'Vehicle Style'], aggfunc='mean')
pivot_table4
# Out:
#                              MSRP
# Make  Vehicle Style
# Acura 2dr Hatchback  17175.607143
#       4dr Hatchback  51062.857143
#       4dr SUV        42959.758065
#       Coupe          39687.400000
#       Sedan          33292.263566
# ...                           ...
# Volvo 4dr SUV        45338.028169
#       Convertible    40533.333333
#       Coupe           2000.000000
#       Sedan          20869.450000
#       Wagon          24785.418367
#
# [286 rows x 1 columns]

# %% [markdown]
# # Calculate the average MSRP for each combination of transmission type and body style using  Pivot Tables.

# %%
pivot_table5 = car.pivot_table(values='MSRP', index='Transmission Type', columns='Vehicle Style', aggfunc='mean')
pivot_table5
# Out:
# Vehicle Style      2dr Hatchback       2dr SUV  4dr Hatchback       4dr SUV
# Transmission Type
# AUTOMATED_MANUAL    27180.964912           NaN   29249.074074  40451.153846  \
# AUTOMATIC           20926.464000  18615.204545   23833.678977  41555.188245
# DIRECT_DRIVE                 NaN           NaN   34511.923077           NaN
# MANUAL              13353.658307   6303.811111   17594.413127  15426.462264
# UNKNOWN              7361.500000   2371.000000            NaN           NaN
#
# Vehicle Style      Cargo Minivan     Cargo Van    Convertible
# Transmission Type
# AUTOMATED_MANUAL             NaN           NaN  121256.644444  \
# AUTOMATIC           20910.857143  15280.221053   90637.386905
# DIRECT_DRIVE                 NaN           NaN            NaN
# MANUAL                       NaN           NaN   62357.756250
# UNKNOWN                      NaN           NaN    5783.500000
#
# Vehicle Style      Convertible SUV          Coupe  Crew Cab Pickup
# Transmission Type
# ...

# %% [markdown]
# # Calculate the average MPG for each combination of body style and model year using Pivot Tables

# %%
pivot_table6 = car.pivot_table(values='highway MPG', columns='Year', index='Vehicle Style', aggfunc='mean')
pivot_table6
# Out:
# Year                      1990       1991       1992       1993       1994
# Vehicle Style
# 2dr Hatchback        30.400000  30.066667  29.696970  28.533333  27.350000  \
# 2dr SUV              20.000000  16.250000  17.470588  18.473684  18.428571
# 4dr Hatchback        31.000000        NaN  28.375000  27.300000  27.142857
# 4dr SUV                    NaN  19.333333  21.333333  21.000000  20.000000
# Cargo Minivan        20.000000        NaN        NaN        NaN  21.000000
# Cargo Van                  NaN        NaN        NaN        NaN  19.333333
# Convertible          23.500000  22.625000  25.500000  24.461538  26.000000
# Convertible SUV            NaN        NaN        NaN  26.000000  26.000000
# Coupe                24.500000  26.157895  27.285714  28.461538  27.478261
# Crew Cab Pickup            NaN        NaN        NaN        NaN        NaN
# Extended Cab Pickup  22.000000  15.833333  15.600000  16.714286  20.285714
# ...

# %% [markdown]
# # Calculate the average horsepower, MPG, and MSRP for each car brand using  Pivot Tables.

# %%
pivot_table7 = car.pivot_table( index='Make', values=['Year','Engine HP','Engine Cylinders','Number of Doors','highway MPG','city mpg','Popularity','MSRP'], aggfunc='mean')
pivot_table7
# Out:
#                Engine Cylinders    Engine HP          MSRP  Number of Doors
# Make
# Acura                  5.333333   244.797619  3.488759e+04         3.619048  \
# Alfa Romeo             4.000000   237.000000  6.160000e+04         2.000000
# Aston Martin          10.623656   484.322581  1.979104e+05         2.150538
# Audi                   5.557927   277.695122  5.345211e+04         3.469512
# BMW                    5.958084   326.907186  6.154676e+04         3.161677
# Bentley                9.729730   533.851351  2.471693e+05         2.675676
# Bugatti               16.000000  1001.000000  1.757224e+06         2.000000
# Buick                  5.316327   219.244898  2.820661e+04         3.836735
# Cadillac               6.433249   332.309824  5.623132e+04         3.602015
# Chevrolet              5.907623   247.056502  2.827336e+04         3.376682
# Chrysler               5.593583   229.139037  2.672296e+04         3.625668
# ...

# %% [markdown]
# # Do regression analysis to identify the variables that have the strongest relationship with a car's price.

# %%
import statsmodels.api as sm

# Define the predictor variables
X = car[['Year','Engine HP','Engine Cylinders','Number of Doors','highway MPG','city mpg','Popularity','MSRP']]

# Add a constant term to the predictor variables
X = sm.add_constant(X)

# Define the response variable
y = car['MSRP']

# Fit a linear regression model
model = sm.OLS(y, X).fit()

# Print the model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   MSRP   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.971e+33
# Date:                Sun, 11 Jun 2023   Prob (F-statistic):               0.00
# Time:                        13:38:40   Log-Likelihood:             2.6705e+05
# No. Observations:               11812   AIC:                        -5.341e+05
# Df Residuals:                   11803   BIC:                        -5.340e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -6.155e-09   1.25e-10    -49.054      0.000    -6.4e-09   -5.91e-09
# ...

# %% [markdown]
# ### random analysis of data

# %%
car2['Market Category'].unique
# Out:
# <bound method Series.unique of 0        Factory Tuner,Luxury,High-Performance
# 1                           Luxury,Performance
# 2                      Luxury,High-Performance
# 3                           Luxury,Performance
# 4                                       Luxury
#                          ...
# 11807               Crossover,Hatchback,Luxury
# 11808               Crossover,Hatchback,Luxury
# 11809               Crossover,Hatchback,Luxury
# 11810               Crossover,Hatchback,Luxury
# 11811                                   Luxury
# Name: Market Category, Length: 8084, dtype: object>

# %%
car2['Popularity'].unique
# Out:
# <bound method Series.unique of 0        3916
# 1        3916
# 2        3916
# 3        3916
# 4        3916
#          ...
# 11807     204
# 11808     204
# 11809     204
# 11810     204
# 11811      61
# Name: Popularity, Length: 8084, dtype: int64>

# %%
car2['Market Category'].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0        Factory Tuner,Luxury,High-Performance
# 1                           Luxury,Performance
# 2                      Luxury,High-Performance
# 3                           Luxury,Performance
# 4                                       Luxury
#                          ...
# 11807               Crossover,Hatchback,Luxury
# 11808               Crossover,Hatchback,Luxury
# 11809               Crossover,Hatchback,Luxury
# 11810               Crossover,Hatchback,Luxury
# 11811                                   Luxury
# Name: Market Category, Length: 8084, dtype: object>

# %%
car2.describe
# Out:
# <bound method NDFrame.describe of           Make       Model  Year                Engine Fuel Type  Engine HP
# 0          BMW  1 Series M  2011     premium unleaded (required)        335  \
# 1          BMW    1 Series  2011     premium unleaded (required)        300
# 2          BMW    1 Series  2011     premium unleaded (required)        300
# 3          BMW    1 Series  2011     premium unleaded (required)        230
# 4          BMW    1 Series  2011     premium unleaded (required)        230
# ...        ...         ...   ...                             ...        ...
# 11807    Acura         ZDX  2012     premium unleaded (required)        300
# 11808    Acura         ZDX  2012     premium unleaded (required)        300
# 11809    Acura         ZDX  2012     premium unleaded (required)        300
# 11810    Acura         ZDX  2013  premium unleaded (recommended)        300
# 11811  Lincoln      Zephyr  2006                regular unleaded        221
#
# ...

# %%
car2.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
x1 = car2['Market Category'].head(20)
y1 = car2['Popularity'].head(20)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 16
#      11 ax2 = ax1.twinx()
#      13 # Plot line chart for another variable (if available)
#      14 # Example: Sales data
#      15 #sales = [100, 150, 80, 120]
# ---> 16 ax2.plot( car2['Market Category'] , car2['Popularity'] , color='red', marker='o', data=car2)
#      17 #ax2.set_ylabel('Popularity')
#      18
#      19 # Display the combo chart
#      20 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
# ...

# %%
car[car['Make']== 'BMW']
car.head(9)
corr_coeff = car['Engine Cylinders'].corr(car['highway MPG'])
corr_coeff
# Out:
# -0.6203125511154071

# %%
car.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP
# 0  BMW  1 Series M  2011  premium unleaded (required)        335  \
# 1  BMW    1 Series  2011  premium unleaded (required)        300
# 2  BMW    1 Series  2011  premium unleaded (required)        300
# 3  BMW    1 Series  2011  premium unleaded (required)        230
# 4  BMW    1 Series  2011  premium unleaded (required)        230
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors
# 0                 6            MANUAL  rear wheel drive                2  \
# 1                 6            MANUAL  rear wheel drive                2
# 2                 6            MANUAL  rear wheel drive                2
# 3                 6            MANUAL  rear wheel drive                2
# 4                 6            MANUAL  rear wheel drive                2
#
#                          Market Category Vehicle Size Vehicle Style
# ...

# %%
filtered_cars = car[(car["Make"] == "BMW") & (car["Model"] == "1 Series M")].Make
print(filtered_cars)

# %%
filtered_cars = car[(car["Engine HP"] >300)]
print(filtered_cars)
# Out:
#       Make       Model  Year             Engine Fuel Type  Engine HP
# 0      BMW  1 Series M  2011  premium unleaded (required)        335  \
# 15     BMW    1 Series  2013  premium unleaded (required)        320
# 16     BMW    1 Series  2013  premium unleaded (required)        320
# 43     BMW    2 Series  2016  premium unleaded (required)        320
# 46     BMW    2 Series  2016  premium unleaded (required)        320
# ...    ...         ...   ...                          ...        ...
# 11797  BMW          Z4  2015  premium unleaded (required)        335
# 11800  BMW          Z4  2016  premium unleaded (required)        335
# 11801  BMW          Z8  2001  premium unleaded (required)        394
# 11802  BMW          Z8  2002  premium unleaded (required)        394
# 11803  BMW          Z8  2003  premium unleaded (required)        394
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors
# ...

# %%
# Assuming you have a DataFrame named 'data' with 'market_category' and 'popularity' columns

# Group the data by market category and calculate the average popularity
average_popularity = car.groupby('Market Category')['Popularity'].mean().reset_index()

# Sort the categories by popularity in descending order
average_popularity = average_popularity.sort_values('Popularity', ascending=False)

# Set up the figure and axes
fig, ax1 = plt.subplots(figsize=(13, 8))

# Create the bar plot for popularity
sns.barplot(x='Market Category', y='Popularity', data=average_popularity, ax=ax1, color='grey')

# Set the y-axis label for the bar plot
ax1.set_ylabel('Popularity')

# Create the line plot for popularity
ax2 = ax1.twinx()
sns.lineplot(x='Market Category', y='Popularity', data=average_popularity, ax=ax2, marker='o', color='black')

# Set the y-axis label for the line plot
ax2.set_ylabel('Popularity')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Set the title of the chart
plt.title('Relationship between Market Category and Popularity')

# Display the chart
plt.show()

# %%
fig, ax = plt.subplots(figsize=(13, 8))
#this line of code creates a new figure with a specific size of 10 inches by 6 inches and assigns the figure object to the variable fig 
#and the subplot object to the variable ax. 
# Create the scatter plot
sns.scatterplot(x='Engine HP', y='MSRP', data=car, ax=ax)

# Add a trendline using seaborn's regplot
sns.regplot(x='Engine HP', y='MSRP', data=car, ax=ax)

# Set the title of the chart
plt.title('Engine Power vs. Price')

# Display the chart
plt.show()

# %%
# Assuming you have a DataFrame named 'data' with 'manufacturer' and 'price' columns

# Calculate the average price by manufacturer
average_price = car.groupby('Make')['MSRP'].mean().reset_index()

# Sort the manufacturers by average price in descending order
average_price = average_price.sort_values('MSRP', ascending=False)

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(15, 9))

# Create the bar chart
plt.barh(average_price['Make'], average_price['MSRP'], color='red',width = 0.1)

# Set the x-axis label
ax.set_xlabel('Average Price')

# Set the y-axis label
ax.set_ylabel('Manufacturer')

# Set the title of the chart
plt.title('Relationship between Manufacturer and Average Price')

# Display the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 13
#      10 fig, ax = plt.subplots(figsize=(15, 9))
#      12 # Create the bar chart
# ---> 13 plt.barh(average_price['Make'], average_price['MSRP'], color='red',width = 0.1)
#      15 # Set the x-axis label
#      16 ax.set_xlabel('Average Price')
#
# TypeError: barh() got multiple values for argument 'width'

# %%
average_price = car.groupby('Make')['MSRP'].mean().reset_index()

# Sort the manufacturers by average price in descending order
average_price = average_price.sort_values('MSRP', ascending=False)

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(15, 9))

# Create the bar chart
plt.barh(average_price['Make'], average_price['MSRP'], color='grey')

# Set the x-axis label
ax.set_xlabel('Average Price')

# Set the y-axis label
ax.set_ylabel('Manufacturer')

# Set the title of the chart
plt.title('Relationship between Manufacturer and Average Price')

# Display the chart
plt.show()

# %%
# Assuming you have a DataFrame named 'data' with 'number_of_cylinders' and 'highway_mpg' columns

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(13, 8))

# Create the scatter plot
sns.scatterplot(x='Engine Cylinders', y='highway MPG', data=car, ax=ax,color='grey')

# Add a trendline using seaborn's regplot
sns.regplot(x='Engine Cylinders', y='highway MPG', data=car, ax=ax,color='red')

# Set the title of the chart
plt.title('Number of Cylinders vs. Highway MPG')

# Display the chart
plt.show()

# %%
car
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP
# 0          BMW  1 Series M  2011     premium unleaded (required)        335  \
# 1          BMW    1 Series  2011     premium unleaded (required)        300
# 2          BMW    1 Series  2011     premium unleaded (required)        300
# 3          BMW    1 Series  2011     premium unleaded (required)        230
# 4          BMW    1 Series  2011     premium unleaded (required)        230
# ...        ...         ...   ...                             ...        ...
# 11807    Acura         ZDX  2012     premium unleaded (required)        300
# 11808    Acura         ZDX  2012     premium unleaded (required)        300
# 11809    Acura         ZDX  2012     premium unleaded (required)        300
# 11810    Acura         ZDX  2013  premium unleaded (recommended)        300
# 11811  Lincoln      Zephyr  2006                regular unleaded        221
#
# ...

# %%
pivot_table1 = car.pivot_table(values='Popularity', index='Market Category', columns='Make', aggfunc=['count', 'mean'])
pivot_table1
# Out:
#                                                 count
# Make                                            Acura Alfa Romeo Aston Martin
# Market Category
# Crossover                                         NaN        NaN          NaN  \
# Crossover,Diesel                                  NaN        NaN          NaN
# Crossover,Exotic,Luxury,High-Performance          NaN        NaN          NaN
# Crossover,Exotic,Luxury,Performance               NaN        NaN          NaN
# Crossover,Factory Tuner,Luxury,High-Performance   NaN        NaN          NaN
# ...                                               ...        ...          ...
# Luxury,Hybrid                                     2.0        NaN          NaN
# Luxury,Performance                               57.0        NaN          NaN
# Luxury,Performance,Hybrid                         NaN        NaN          NaN
# Performance                                       NaN        NaN          NaN
# ...

# %%
# Assuming you have a DataFrame named 'data' with 'brand', 'body_style', and 'MSRP' columns

# Filter the data for specific brands or body styles if desired
filtered_data = car  # Replace with your filter conditions

# Calculate the total MSRP for each brand and body style using groupby and sum
grouped_data = filtered_data.groupby(['Make', 'Vehicle Style'])['MSRP'].sum().unstack()

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Create the stacked column chart
grouped_data.plot(kind='bar',  ax=ax)

# Set the x-axis label
ax.set_xlabel('Brand')

# Set the y-axis label
ax.set_ylabel('Total MSRP')

# Set the title of the chart
plt.title('Distribution of Car Prices by Brand and Body Style')

# Add a legend
plt.legend(title='Body Style')

# Display the chart
plt.show()

# %%
grouped_data = car.groupby(['Make', 'Vehicle Style'])['MSRP'].mean().unstack()

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(13, 8))

# Create the clustered column chart
grouped_data.plot(kind='bar', ax=ax)

# Set the x-axis label
ax.set_xlabel('Brand')

# Set the y-axis label
ax.set_ylabel('Average MSRP')

# Set the title of the chart
plt.title('Comparison of Average MSRPs by Brand and Body Style')

# Add a legend
plt.legend(title='Body Style')

# Display the chart
plt.show()

# %%
# Assuming you have a DataFrame named 'data' with 'MSRP', 'transmission_type', and 'body_style' columns

# Calculate the average MSRP for each combination of transmission type and body style using groupby and mean
grouped_data = car.groupby(['Transmission Type', 'Vehicle Style'])['MSRP'].mean()

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Create the scatter plot with different symbols for each body style
for body_style, group in car.groupby('Vehicle Style'):
    ax.scatter(group['MSRP'], group['Transmission Type'], label=body_style)

# Set the x-axis label
ax.set_xlabel('MSRP')

# Set the y-axis label
ax.set_ylabel('Transmission Type')

# Set the title of the chart
plt.title('Relationship between MSRP and Transmission Type')

# Add a legend
plt.legend(title='Body Style',loc='upper right')

# Display the chart
plt.show()

# %%
# Assuming you have a DataFrame named 'data' with 'MPG', 'body_style', and 'model_year' columns

# Calculate the average MPG for each combination of body style and model year using groupby and mean
grouped_data = car.groupby(['Vehicle Style', 'Make'])['highway MPG'].mean().unstack()

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Create the line chart for each body style
for body_style, group in grouped_data.groupby('Vehicle Style'):
    group.plot('Vehicle Style', body_style, ax=ax, label=body_style)

# Set the x-axis label
ax.set_xlabel('Model Year')

# Set the y-axis label
ax.set_ylabel('MPG')

# Set the title of the chart
plt.title('Trend of Fuel Efficiency (MPG) over Time for Each Body Style')

# Add a legend
plt.legend()

# Display the chart
plt.show()

# %%
# Assuming you have a DataFrame named 'data' with 'horsepower', 'MPG', 'price', 'brand', and 'model_name' columns

# Calculate the average horsepower, MPG, and MSRP for each car brand using groupby and mean
grouped_data = car.groupby('Make').agg({'Engine HP': 'mean', 'highway MPG': 'mean', 'MSRP': 'mean'})

# Set up the figure and axes
fig, ax = plt.subplots(figsize=(10, 6))

# Create the bubble chart
for brand, group in car.groupby('Make'):
    ax.scatter(group['Engine HP'], group['highway MPG'], s=group['MSRP']/1000, alpha=0.7, label=Make)

    # Add labels to the bubbles
    for i, model_name in enumerate(group['Model']):
        ax.text(group['Engine HP'].iloc[i], group['highway MPG'].iloc[i], Model, ha='center', va='center', fontsize=8)

# Set the x-axis label
ax.set_xlabel('Horsepower')

# Set the y-axis label
ax.set_ylabel('MPG')

# Set the title of the chart
plt.title('Relationship between Horsepower, MPG, and Price across Car Brands')

# Add a legend
plt.legend(title='Brand')

# Display the chart
plt.show()
